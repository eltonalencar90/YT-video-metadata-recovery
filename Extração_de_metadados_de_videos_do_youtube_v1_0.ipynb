# %% [markdown]
# <a href="https://colab.research.google.com/github/eltonalenca90/YT-video-metadata-recovery/blob/main/Extra%C3%A7%C3%A3o_de_metadados_de_videos_do_youtube_v1_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Extração de metadados de videos do youtube**
#
# **Criado por** : Elton Alencar e Victoria Guimaraes({enda;vsg}@icomp.ufam.edu.br)
#
# **Descrição:** Código desenvolvido para busca de videos no Youtube e extração de metadados e caption, utilizando a API do YOUTUBE
#
# **última atualização**: 10/27/2021
#
# Referências:
# https://developers.google.com/youtube/v3/docs/search?hl=pt-br
# https://pypi.org/project/youtube-transcript-api/

# %% [markdown]
# # Imports *

# %%
#instalando biblioteca
# !pip install youtube_transcript_api
# !pip install gspread

#imports
# %reload_ext google.colab.data_table
from google.colab import data_table
from apiclient.discovery import build
import pandas as pd
import numpy as np
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import time
from youtube_transcript_api import YouTubeTranscriptApi
# Out:
# Collecting youtube_transcript_api
#   Downloading youtube_transcript_api-0.4.1-py3-none-any.whl (22 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from youtube_transcript_api) (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->youtube_transcript_api) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->youtube_transcript_api) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->youtube_transcript_api) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->youtube_transcript_api) (1.24.3)
# Installing collected packages: youtube-transcript-api
# Successfully installed youtube-transcript-api-0.4.1
# Requirement already satisfied: gspread in /usr/local/lib/python3.7/dist-packages (3.0.1)
# Requirement already satisfied: requests>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from gspread) (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.2.1->gspread) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.2.1->gspread) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.2.1->gspread) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.2.1->gspread) (2.10)

# %% [markdown]
# #Funções e Métodos *

# %%
def buscar_canais_por_nome(nome, youtube):
  request = youtube.search().list(q=nome, part='snippet', type='channel', maxResults=10)
  response = request.execute()
  return response

def criar_nova_planilha(nome, numLinhas, numColumn, shClient):
  #cria uma pagina para cada uma nova página na planilha
  shClient.add_worksheet(nome, numLinhas, numColumn)

def cria_varias_planilhas(listNomes, numLinhas, numColumn, shClient):
  #cria uma tabela para cada canal
  for i in range(len(listNomes)):
    shClient.add_worksheet('{}'.format(listNomes[i]), 100, 10)
  print('criou')  

#acessando os ids do videos 
def get_videosID(videos):
  ids_videos = [] #estrutura de dados que armazenara os ids dos 50 videos
  for i in range(len(videos['items'])): #enquanto i estiver no intervalo de [0, 'quantidade de elementos da lista videos']
    ids_videos.append(videos['items'][i]['id']['videoId']) #adiciona o id do video (que está na posição i da lista videos[items])
  return ids_videos #retorna como resposta a lista ids_video

#acessando os 'channelTitle' 
def get_channelsTitle(res):
  channels = []
  for i in range(len(res['items'])):
    channels.append(res['items'][i]['snippet']['channelTitle'])
  return channels 

#acessando os titles 
def get_titles(res):
  titles = []
  for i in range(len(res['items'])):
    titles.append(res['items'][i]['snippet']['title'])
  return titles    

#acessando os 'publishTime' 
def get_publishDate(res):
  timestamps = []
  for i in range(len(res['items'])):
    timestamps.append(res['items'][i]['snippet']['publishTime'])
  return timestamps

#acessando os 'description' 
def get_descriptions(res):
  descriptions = []
  for i in range(len(res['items'])):
    descriptions.append(res['items'][i]['snippet']['description'])
  return descriptions

#função que adiciona os valores desejados numa lista 
def get_statistic_key(videos_statistic, keyDesejada):
  listaValues = []
  for i in range(len(videos_statistic)):
    if keyDesejada in videos_statistic[i]['statistics']: #verifica se o video atual possui os valores de key
      listaValues.append(videos_statistic[i]['statistics'][keyDesejada])
    else:
      listaValues.append('null')
  return listaValues

#busca pelos videos desejados (termo de consulta) em cada canal
#extrai caracteristicas desejadas (title, desc, numviews...)
#salva num csv
def busca_por_termo(termo_de_busca, apartirDe):

  arquivo = open("{}.txt".format(termo_de_busca), "a")

  df_all_data_returned = pd.DataFrame()

  lista_de_videos = youtube.search().list(q=termo_de_busca, part='snippet', type='video', maxResults=50, publishedAfter=apartirDe).execute() 
  if (len(lista_de_videos['items']) != 0):
    #extração de dados desejados
    lista_videosID = get_videosID(lista_de_videos)
    timestamps_v = get_publishDate(lista_de_videos)
    titles_videos = get_titles(lista_de_videos)
    channelsName = get_channelsTitle(lista_de_videos)  
    descriptionList = get_descriptions(lista_de_videos)

    # Call the videos.list method to retrieve statistics details for each video.
    video_response = youtube.videos().list(id=lista_videosID, part='statistics').execute()
    videos_statistic = video_response.get('items', [])

    # Select a likesCount_list
    likesCount_list = get_statistic_key(videos_statistic, 'likeCount')
    # Select a likesCount_list
    viewsCount_list = get_statistic_key(videos_statistic, 'viewCount')
    # Select a commentCount_list
    commentCount_list = get_statistic_key(videos_statistic, 'commentCount')
    # Select a dislikeCount_list
    dislikeCount_list = get_statistic_key(videos_statistic, 'dislikeCount')

    df_search = {
        'id': lista_videosID,
        'title': titles_videos,
        'channel': channelsName,
        'date_p': timestamps_v,
        'description': descriptionList,
        'views': likesCount_list,
        'likes': viewsCount_list,
        'dislikes': dislikeCount_list,
        'comments': commentCount_list
      }

    columns = [
        'id',
        'title',
        'channel',
        'date_p',
        'description',
        'views',
        'likes',
        'dislikes',
        'comments'
    ]

    df_all_data_returned = pd.DataFrame(df_search, columns=columns)
    print(df_all_data_returned.shape)

  return df_all_data_returned

# %% [markdown]
# # Módulo 1:
#
# * Extração de dados
# * Organização de dados
# * Permanencia de dados

# %% [markdown]
# ##Conectando com API
# * youtube-v3

# %% [markdown]
# ### Youtube v3

# %%
#TODO : substituir com o valor da chave da API gerada por vc:
API_KEY = "AIzaSyBZXYtvA7******************4Q4" #chave de autenticação do projeto, para acesso dos dados

# %%
#Construct a Resource object for interacting with an API. The serviceName and version are the names from the Discovery service.
youtube = build('youtube', 'v3', developerKey=API_KEY)
type(youtube)
# Out:
# googleapiclient.discovery.Resource

# %% [markdown]
# ## Video Recovery - Busca de Videos
# * busca de videos por canal
# * extração de dados desejados
# * busca com diferentes TERMOS DE CONSULTA

# %% [markdown]
# ### Pesquisa por diferentes Termos de Busca

# %% [markdown]
# #### Novas Buscas
#
# Processo:
#
# * 1. busca de dados, pelo termo
# * 2. coloca no banco de dados (concatena)
# * 3. remove duplicados
# * 4. get captions para os ids novos
# * 5. coloca os novos captions no df criado no passo 2
# * 6.

# %%
termo_de_busca = 'extração de dados do youtube'
publicaçõesApartir = '2021-05-01T00:00:00Z'
df_dados_retornados = busca_por_termo(termo_de_busca, publicaçõesApartir)
# Out:
# (50, 9)

# %%
#vizualizando dados buscados: 
df_dados_retornados.head(10)
# Out:
#             id  ... comments
# 0  0spvJseeYHU  ...       11
# 1  WHBp211rifg  ...        0
# 2  6Fgo3V90woQ  ...        1
# 3  zWpJGsYVn_I  ...        6
# 4  YBtMx6JBlwo  ...        2
# 5  qQn2jY2nuAA  ...        1
# 6  osa0kxdiFm8  ...      174
# 7  uLL006Xk4b4  ...        0
# 8  xxOGZa5HZG8  ...        2
# 9  3vJGJ5i1ilg  ...       13
#
# [10 rows x 9 columns]

# %% [markdown]
# ##### Salvando em um csv

# %%
from google.colab import files
nomeDoArquivo = 'all_videos_metadados.csv'
df_dados_retornados.to_csv(r'all_videos_metadados.csv', index = False)
files.download(nomeDoArquivo) #download do csv

# %% [markdown]
# #####Get Captions:
# Busca por caption [legenda gerada automática] para cada um dos videos retornados no df_retornado
#
# source: https://pypi.org/project/youtube-transcript-api/

# %%
allIds = df_dados_retornados.id.values
null_lista = []
allCaptions = []

while True:
  for i in range(len(allIds)):
    try:
      #acessa o caption do video e add na lista de allCaptions
      caption = YouTubeTranscriptApi.get_transcript(allIds[i], ['pt'])
      allCaptions.append(caption)
      print(str(i) + ': ' + allIds[i])
      time.sleep(6)
    except:
      #caso não tenha caption
      null_lista.append(i) #salvo o index do id que não tem caption
      allCaptions.append(['NULL']) #add null lista allCaption 
      i+=1 #incrementa i atual
      continue #continua task
  break
# Out:
# 0: 0spvJseeYHU
# 2: 6Fgo3V90woQ
# 3: zWpJGsYVn_I
# 4: YBtMx6JBlwo
# 5: qQn2jY2nuAA
# 6: osa0kxdiFm8
# 7: uLL006Xk4b4
# 8: xxOGZa5HZG8
# 9: 3vJGJ5i1ilg
# 10: K30TpP1JM5k
# 11: Et9FYt6ZZB8
# 12: t7tlMdyZ6HM
# 14: xXl_hFWMkaE
# 15: US4YC9DvHJE
# 16: ujFHKTAIi0k
# 17: JbOROfflpr0
# 18: 5CHLH9LU1Uc
# 19: rMTf6MnP8Ps
# 20: OGudoUMqNpw
# 21: dRcA_2Xw2FU
# 23: ti-njetItug
# 24: kOqYHNlCmbg
# 25: v2S-WH3JCBo
# 26: Dc4lqcR66Ls
# 27: nfAqwiH_CFg
# 28: BPgXu2wjOcs
# 29: IlUz8klip5I
# 30: TeeoYeMAXkY
# 31: Phs_OD1MN6M
# 32: uAByChUOpdM
# 34: djV9Hkk7DFU
# 35: pC3wmBu1_kY
# 36: WHLBNptrokE
# 37: Nj57VD3xKdk
# 38: jorHmZKROBA
# 39: 66asE8bZ9lA
# 40: djQIeGMaHt8
# 41: -uMAnkxkS5w
# 42: 5adFNM9yASU
# 43: Y4yQaWS1MMA
# 44: OyIKhJ0xg4c
# 47: 7zmRSbztWeU
# 48: SE8SNOF1KLY
# 49: SLwWrM6wRbo

# %%
# %unload_ext google.colab.data_table
df_metadados_com_caption = df_dados_retornados
df_metadados_com_caption['captions']=allCaptions
df_metadados_com_caption.head(5)
# Out:
#             id  ...                                           captions
# 0  0spvJseeYHU  ...  [{'text': 'e', 'start': 0.54, 'duration': 2.97...
# 1  WHBp211rifg  ...                                             [NULL]
# 2  6Fgo3V90woQ  ...  [{'text': 'o', 'start': 0.0, 'duration': 4.14}...
# 3  zWpJGsYVn_I  ...  [{'text': 'Oi tudo bem', 'start': 0.0, 'durati...
# 4  YBtMx6JBlwo  ...  [{'text': 'e vamos continuar', 'start': 1.23, ...
#
# [5 rows x 10 columns]

# %%
#estrutura de um item do caption
df_metadados_com_caption.captions.values[0][1]
# Out:
# {'duration': 5.25,
#  'start': 1.1,
#  'text': 'fala galera então estamos aqui novamente'}

# %%
#extraindo somente o texto caption[legenda] do video 0  
c = df_metadados_com_caption.captions.values
for i in c[0]:
    print(i['text'])
# Out:
# e
# fala galera então estamos aqui novamente
# apresentando para vocês a estabilidade
# 4.0 É isso mesmo as paredes aí tá de
# cara nova com novas funcionalidades e se
# tornando aí a líder do mercado
# deles se tratando sobre infrações né
# tamo junto como sempre o começo aí
# respeitando a todos os nossos
# concorrentes então tem funcionalidades
# novas e Aquino Itália e não tem o nossos
# concorrentes Mas como eu digo sempre né
# Livre Mercado Pode ser que eles copiem
# nossas funcionalidades eu só queria dar
# um recado importante falar para vocês
# que a está linda ela só é comercializada
# aqui no nosso canal do YouTube que tem
# um link que leva com a nossa página quem
# está beach.com.br ou e no nosso parceiro
# de vendas que é o Frank que o site dele
# hesa puro
# mais.com.br que também comercializa
# instale Então são dois canais é que
# realizam as vendas é infelizmente as
# versões anteriores elas foram criadas e
# a gente tem uma diferença é muito
# engraçado porque assim a ferramenta
# criada ela custa mais cara do que a
# ferramenta original e aí tem uma
# diferença que a ferramenta original ela
# tem login sem E aí pegaram a ferramenta
# colocaram up acho que escrito aqui em
# cima top vídeo é normal né todos todas
# as grandes empresas elas sofrem com
# pirataria e não seria diferente com a
# gente isso só mostra que a gente está no
# caminho certo fazendo trabalho certo né
# fazendo um trabalho honesto e fazendo
# trabalho certo E aí respeitando a todos
# do mercado então é lembrando aí desses
# dois canais de vendas a está linda ela
# tem um preço muito acessível
# justamente para Me manda o nosso Então
# as nossas missões é ajudar né o micro
# empreendedor empreendedor e ainda mais
# nesse tempo pandêmico a realizarem suas
# vendas Então quando você compra
# ferramenta original a primeira questão
# que você tenha a primeira entrega que
# você tenha uma ferramenta livre de vírus
# então eu te desafio aí você pegar uma
# versão anterior que foi crackeada e
# fazer o piloto de lá no site chamado
# virustotal que você vai ver a quantidade
# de vírus que tem a ferramenta enfim até
# o próprio site que vende a ferramenta já
# se chama crack né então que esperar é
# então é isso então tô gravando esse
# vídeo hoje se a ferramenta for pra que
# há de novo é pirateado daqui para frente
# você já tá ciente já tá bom mas não
# tenho muito que a gente fazer então mais
# além de Começando aqui apresentar a
# versão 4.0 é uma das únicas ferramentas
# aí que tem no login e senha online tô a
# partir do momento que você realizou a
# sua compra você já consegue utilizar e
# com seu login e senha de maneira
# automática ou apertar aqui entrar e aí
# uma das vantagens da ferramenta original
# também é o que é você ter essa mensagem
# aqui então as pessoas que se você
# utilizar se você visualizar no nosso
# canal não sei onde você tá vendo esse
# vídeo se você visualizar no nosso canal
# ou aí no YouTube no nosso site no
# YouTube você vai ver que a está linda
# ela percorreu algumas versões é então as
# pessoas que compram essa linha ela
# sempre tem atualizações periodicamente
# elas não são cobradas Tá bom então
# aconteceu alguma coisa atualizou alguma
# funcionalidade você recebe essa
# atualização de maneira na hora que você
# abre a ferramenta você recebe uma
# notificação Falando nisso Olha tem uma
# atualização disponível você deseja
# baixar aula Você clicou em sim ele vai
# baixar aí atualização automaticamente
# então para você que já conhece instale a
# gente tem aqui é a nossa Central aqui de
# contas né e a gente atrás algumas
# mudanças que a as lições na pe isso
# daqui gente é explicado é em todas as
# nossas aulas então além da ferramenta
# gente em treinamento com mais de 30
# aulas é um super treinamento ensinando
# funcionalidade para funcionar
# personalidade dicas é como você utilizar
# Como utilizar da maneira certa como ter
# contas como não tomar banho em trocentos
# e outras funcionalidades e dicas ali que
# você tem exclusiva no Nossos Vídeos né
# quando você compra ferramenta
# automaticamente você recebe um
# treinamento para além do nosso suporte
# que funciona de segunda a sexta
# Então vamos lá uma das coisas que a
# gente inovou na 3.2 e agora a gente
# renovou na 4.0 é a saúde das contas
# então saúde das contas a gente consegue
# ter um controle total agora do que tá
# acontecendo com as contas nos processos
# de Estações eu não vou explicar as
# funcionalidades aqui e de maneira mais
# extensa só vou fazer um ver viu então a
# gente consegue saber é
# qual é o motivo da extração Qual é a
# data quantas requisições foram feitas
# então a gente consegue ter um controle
# maior para diminuir drasticamente o
# índice de banho então é o Instagram e
# tem mais de 35 é critérios de banimentos
# então isso já acontece maneira
# automática aqui na nossa saúde das
# contas e aí como o desafio né eu desafio
# você a tentar encontrar essas
# funcionalidades em essa opção aí em
# outras ferramentas tá bom Outra coisa
# também para deixar a concorrência maluca
# e você também e agora estaria de não tem
# delay Cadê o dele não atenderem é a
# gente está trabalhando com a p i sem por
# cento agora tudo dentro da nossas fundo
# do nosso corpo então todo dele ele tá
# configurado dentro do nosso Cola então
# entrega é muito absurdo muito absurdo eu
# vou fazer uns testes aqui para vocês
# então vamos lá eu vou entrar aqui ó na
# extrair seguidores então uma das coisas
# que mudou aqui na extração de seguidores
# é o que mais tá lide é a única
# ferramenta que alterna as contas aqui na
# estação de seguidores então é uma das
# nossas aulas a gente consegue eu tenho
# aqui uma extração de 46 1674 seguidores
# a gente faz isso em apenas
# 8 minutos e aí eu desafio você e
# utilizando duas contas aí eu desafio
# você a testar isso em outra ferramenta é
# e ver quanto tempo você vai demorar mais
# uma eu vou colocar aqui ó o usuário aqui
# ó e vou colocar aqui um limite de 1000
# Tá bom então se eu apertar aqui o buscar
# Total servidores automaticamente ele vai
# me trazer a quantidade total de
# seguidores desse usuário aqui isso
# também você só encontra na Itália mas eu
# vou colocar aqui mil vou deixar o tempo
# rodar aqui e vou apertar executar Tá bom
# você vai ver quanto tempo vai demorar
# para extrair mil seguidores vamos lá e
# aí de novo lançando o desafio novamente
# se você encontrar esse em outra
# ferramenta eu poderia muito bem pegar
# uma ferramenta concorrente colocar aqui
# do lado e colocar para extrair mil lá e
# colocar para estarem mil aqui na strid e
# você ia ver a diferença Tá bom
# então até agora ele já me trouxe aqui
# 607
# tu trocou minha conta atualizar a tabela
# Então você tá vendo aqui o Landim né
# carregar né E aí vamos esperar aqui
# quanto tempo demora o pessoal Acho que
# nem um minuto
# e vamos esperar mais um pouquinho aqui ó
# o que a gente poderia muito bem pegar
# uma ferramenta E concorrente colocado
# lado buscas concluídas com sucesso e aí
# você me pergunta qual é o Anderson cadê
# a Lelê não tem delay
# não tem delay então
# é incrível não é não tem não tem no
# mercado agora uma ferramenta igual a
# instabilidade e essa é uma das vantagens
# pessoal E você tem uma ferramenta
# original uma ferramenta é 100 porcento
# certa que não vai prejudicar seu
# computador que você tem atualização
# sempre que você tem um preço acessível E
# aí vai muito da da escolha né é da
# escolha de você e uma ferramenta é
# original ou não existe uma ferramenta no
# mercado ainda existe uma ferramenta no
# mercado chamada Turbo irrita perdoar
# lindo uma das coisas que o Aline me
# falou e até vou ficar esse no vídeo aqui
# que assim é o dia que você tiver uma
# ferramenta pirateada
# você vai ver e vai vai sentir né como é
# a sensação e realmente pessoal é é muito
# complicado você trabalhar é dias de
# programação horas noite sem fim e essa
# ferramenta cair na mão aí desses
# craqueiros desses Piratas na vida aí
# quem que nada mais é do que um roubo né
# tá roubando nosso trabalho mas enfim
# mas a gente aprende muito com isso né é
# um aprendizado para mim então vamos ver
# aqui ó a gente demorou um minuto aqui
# para extrair mil seguidores
# sem Lê não tem dele então eu consigo
# aqui extrair 50 mil
# 40.100 mil um tempo recorde muito rápido
# então coloquei aqui para estar esses mil
# aqui e olha só outra coisa que você só
# encontra na está livre eu tô trazendo
# aqui somente os perfis abertos é
# Lembrando que a está legal a respeito é
# depender Então ela só vai buscar o
# telefone e-mail de pessoas que dei e
# esses dados disponíveis a ferramenta não
# pega telefone e-mail de perfil Privado
# não pega ela simplesmente é uma
# ferramenta de automação ela faz uma ação
# que você demoraria horas para fazer de
# maneira automática então todos esses
# contatos eles estão disponíveis Tá bom
# então automaticamente a ferramenta elas
# a filtra todos os perfis que tem que são
# privados
# Oi e aí me trouxe um total que d844
# então de mil seguidores daqui da
# Qualicorp
# 844 tem perfil aberto então clique aqui
# enviar para extrair informações
# e ele vai aqui para mim a central
# distrações e aqui gente eu vou fazer um
# teste e aqui também é incrível porque
# assim apertei aqui executar Olha só sem
# delay ele já começa a trazer resultado ó
# e olha só
# e aí realmente eu falando de novo e não
# sendo repetitivo pode comparar não tem
# nenhum problema pode comprar nossa
# ferramenta com qualquer outra ferramenta
# do mercado e você vai verificar aí quais
# são as ferramentas que tinham mais
# entrega é isso para você ver eu estou
# utilizando a mesma conta tá bom
# totalmente que com duas contas julgadas
# e você vê que já tem aqui as requisições
# enfim tem todo um controle aqui para
# você não tomar banho na saúde das contas
# os limites enfim tá bom esse daqui tudo
# é explicado em aula então eu vou deixar
# rodando aqui para você ver a quantidade
# de leite que essa ferramenta tá trazendo
# Tá bom mas vamos lá tem uma outras
# funcionalidades que só tem na história
# Tá bom então vamos por algum acaso parou
# extração deu algum erro acontecer alguma
# eventualidade você tem continuar essa
# extração mais tarde vou apertar que
# parar que que eu posso fazer
# em
# salvar essa lista aqui ó
# Oi ó eu posso simplesmente salvar essa
# lista e continuar essa extração depois
# como a eu venho aqui abre a ferramenta
# de novo vou lá no botão importar'
# importo a lista para cá então eu posso
# salvar lista aqui abri uma janela aqui
# também eu salvar lista
# e eu salvo essa lista e depois eu vou lá
# no botão importar' importa essa lista
# novamente ou eu posso simplesmente
# continuar aqui ó parei ó deseja limpar
# eles antes de prosseguir não eu quero
# continuar ministração Então olha só eu
# tô continuando a extração incrível né
# e eu vou parar aqui só para passar um
# overview Geral das outras
# funcionalidades
# então estar seguindo todo mundo já
# conhece também com buscar total de
# seguindo a ferramenta na tá toda a
# híbrida Então ela funciona assim por
# cento híbrida aí então não tem mais de
# lei em nenhuma das funcionalidades ela
# respeita os limites da saúde das contas
# então a saúde das contas realmente é o
# coração de toda a ferramenta aonde é que
# a gente faz o controle o alto comentar e
# e o envio de Direct eles estão é a única
# ferramenta que utiliza essas
# funcionalidades via web Então abre uma
# janela do navegador
# para diminuir a incidência de ban e tem
# uma outra função aqui que só tem mais
# tarde né como eu sempre digo até agora
# né que a gente não sabe que as pessoas
# vão copiar funcionalidade mas que é a
# fibra habilidade ainda habilidade
# simplesmente é aqui é o primeiro estágio
# e o segundo estágio eles funcionam de
# maneira automática incrivelmente muito
# rápido então vou explicar aqui de
# maneira simples como funcionam eu vou
# colocar aqui ó qualicor
# eu vou colocar aqui
# a 500 e vou colocar aqui 500 também
# então ele é só na hora que eu aperto
# aqui executar ele vai simplesmente fazer
# a etapa um E aí tava dois de maneira
# simples então ele já tá capitando aqui ó
# 500 contatos aqui ele já está extraindo
# ao mesmo tempo
# é isso daqui é incrível você só encontra
# você só vai encontrar isso na própria
# instaryde Tá bom
# eu vou parar o vídeo aqui para não ficar
# para não tomar muito tempo de vocês
# assim 15 minutos de vídeo é um overview
# geral da ferramenta Tá bom então chupar
# aqui
# eu vou deixar então tá bom então essa
# instalite totalmente cara nova com uma
# entrega Absurda absurda você pode
# comparar a está Lídia com qualquer outra
# ferramenta no mercado você tem aí quando
# você compra 7 dias para reembolso então
# você pode você quiser utilizar outras
# ferramentas e você que deseja testar
# você pode comprar esse ali Você pode
# você vai receber todas as aulas Ali você
# vai ter um treinamento completo nós
# treinamento está incluído até como você
# cria conta de maneira certa compra conta
# de maneira certa fornecedores de conta é
# um treinamento incrível completo que
# você recebe junto e você recebe junto da
# ferramenta Tá bom então é isso pessoal
# queria agradecer a vocês nossos clientes
# e a você que tá com interesse na estaria
# de pelo interesse pela sua
# disponibilidade também de assistir esse
# vídeo até o final é queria agradecer aí
# todos no mercado também e mandar um
# abraço se desejar boa vindo aí para todo
# mundo tá bom então é isso aí para você
# que nosso cliente Você já está recebendo
# essa atualização agora de maneira
# automática e para você que deseja
# comprar outra está ferramenta nosso
# suporte e toda nossa equipe está à
# disposição tá bom forte abraço fiquem
# com Deus e boas vindas

# %% [markdown]
# ####Salvando novo csv

# %%
from google.colab import files
nomeDoArquivo = 'all_dados_com_caption.csv'
df_metadados_com_caption.to_csv(r'all_dados_com_caption.csv', index = False)
files.download(nomeDoArquivo) #download do csv
